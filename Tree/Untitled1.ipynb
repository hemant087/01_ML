# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor, plot_tree, export_text
from sklearn.metrics import accuracy_score, mean_squared_error,mean_absolute_error
from sklearn.preprocessing import LabelEncoder

# %%
df = sns.load_dataset("tips")

# %%
df.head()
# Out:
#    total_bill   tip  sex  smoker  day  time  size
# 0       16.99  1.01    0       0    2     0     2
# 1       10.34  1.66    1       0    2     0     3
# 2       21.01  3.50    1       0    2     0     3
# 3       23.68  3.31    1       0    2     0     2
# 4       24.59  3.61    0       0    2     0     4

# %%
X = df.iloc[:,1:]

# %%
X
# Out:
#       tip  sex  smoker  day  time  size
# 0    1.01    0       0    2     0     2
# 1    1.66    1       0    2     0     3
# 2    3.50    1       0    2     0     3
# 3    3.31    1       0    2     0     2
# 4    3.61    0       0    2     0     4
# ..    ...  ...     ...  ...   ...   ...
# 239  5.92    1       0    1     0     3
# 240  2.00    0       1    1     0     2
# 241  2.00    1       1    1     0     2
# 242  1.75    1       0    1     0     2
# 243  3.00    0       0    3     0     2
#
# [244 rows x 6 columns]

# %%
y=df["total_bill"]

# %%
df["day"] = label_encoder.fit_transform(df["day"])
df["sex"] = label_encoder.fit_transform(df["sex"])
df["time"] = label_encoder.fit_transform(df["time"])
df["smoker"] = label_encoder.fit_transform(df["smoker"])

# %%
y
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
label_encoder = LabelEncoder()

# %%
x_train,x_test,y_train,y_test = train_test_split(X,y,random_state=42,test_size=0.2)

# %%
drt = DecisionTreeRegressor(max_depth=2)

# %%
drt.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=2)

# %%
y_predict = drt.predict(x_test)

# %%
y_predict
# Out:
# array([20.49240741, 13.89040541, 25.73238095, 25.73238095, 13.89040541,
#        13.89040541, 13.89040541, 13.89040541, 20.49240741, 20.49240741,
#        20.49240741, 13.89040541, 13.89040541, 13.89040541, 13.89040541,
#        25.73238095, 25.73238095, 20.49240741, 13.89040541, 25.73238095,
#        25.73238095, 25.73238095, 20.49240741, 13.89040541, 25.73238095,
#        13.89040541, 13.89040541, 20.49240741, 25.73238095, 25.73238095,
#        25.73238095, 13.89040541, 25.73238095, 20.49240741, 25.73238095,
#        25.73238095, 13.89040541, 25.73238095, 20.49240741, 13.89040541,
#        13.89040541, 13.89040541, 13.89040541, 25.73238095, 13.89040541,
#        13.89040541, 13.89040541, 25.73238095, 13.89040541])

# %%
mean_squared_error(y_predict,y_test)
# Out:
# 57.43278101431275

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

plt.figure(figsize=(12,8))
plot_tree(drt,
          filled=True,
          feature_names=X.columns,
          rounded=True)
plt.show()
